# %% [markdown]
# # Notes
#
#
#
# * Do we want them to use a SJSU email address or they all need to create Google accounts?
# * Then Google drive tutorial
# * We need to create a shared Gdrive for the program
# * We need some sort of NDA - they can't share these materials?
# * Perhaps do screen recordings of some of the Colab functionality, e.g., loading file from google drive, opening notebooks, even creating account?
#
# ** A few of the tasks could involve them searching for the syntax online! It's like a treasure hunt**
#
#
# ** Need to introduce functions before plotting **

# %% [markdown]
# Day1 Crash Course and Variables
# ===============================

# %% [markdown]
# ## Python Basics with Google Collab

# %% [markdown]
# Python is a great general-purpose programming language, for which data mining and machine learning open source libraries exist.  It is the de facto standard for data mining and machine learning.
#
# The tutorials that we are going to go over in this class are intended to be a quick crash course on Python.
#
# There are great Python tutorials available online (e.g., [Python Tutorial](https://docs.python.org/3/tutorial/index.html)).  You can also audit coursera.com courses focusing on Python for free.

# %% [markdown]
# ### Note on Collab

# %% [markdown]
# There are 2 types of blocks that you can create in a Colab notebook - a text block and a code block.  Comments can also be included in code blocks with a preceding `#` symbol. Code blocks have a small arrow on the very left when you hover over them.  You can click on the arrow to execute the code block.
#
# To create a new block, you can click on the `+Code` or `+Text` button at the top of this nodebook.  For additional information on Colab, please consult the Colab tutorials and documentation.

# %% [markdown]
# ### Hello World

# %% [markdown]
# ![img](http://s3.amazonaws.com/lyah/helloworld.png)
# (<a href="#citeproc_bib_item_2">Lipovaca 2011</a>)
#
# In the new notebook cell, type the following Python code:
#
#     print("Hello World!")
#
# To execute the code, click on the cell and either press `Shift + Enter`

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# In Jupyter notebooks, you can use the `print()` function to display output.

# %%
print("   /|")
print("  / |")
print(" /  |")
print("/___|")
# Out:
#    /|
#   / |
#  /  |
# /___|

# %% [markdown]
# However, you can also just type the variable or expression you want to print, and Jupyter will automatically display the output without the need for the `print()` function.

# %%
"Hello 🌍!"
# Out:
# 'Hello 🌍!'

# %% [markdown]
# ### Python Version

# %% [markdown]
# As programming languages evolve their syntax sometimes changes.  This means that a library written for Python 2.7 may not work in Python 3.0.  To find which Python version is currently running in Colab, we can execute the following command by clicking on the right-facing arrow on the left size of the next code block (hover over the code block for the arrow to show up):

# %%
# To place comments in code blocks, use the '#' symbol at the start of a line
# Comments are ignored by Python
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## Variables and Data types (int, double, char).

# %% [markdown]
# ### Variables

# %% [markdown]
# A `variable` is a &ldquo;named container&rdquo; in which you can place a number, a string, an image, or even an entire dataset.
#
# For example, we can create a variable `x` and store the number $22$ in it as shown below.

# %%
x = 22
x
# Out:
# 22

# %% [markdown]
# We use the `print` function to print the contents of the variable.

# %%
# you can also use the print function to print values of a variable
print(x)
print('x+1 is', x+1)
# Out:
# 22
# x+1 is 23

# %% [markdown]
# Please keep in mind that:
#
# -   The side-effect of any block of code you execute in this notebook is preserved in the **Colab notebook (runtime) environment**
# -   For example, the value of `x` that we set in the block above is still $22$ in the block below, assuming you didn&rsquo;t in the meantime (in between the blocks above and below) execute some other code from another block in the notebook which changed ****x****.

# %%
x
# Out:
# 22

# %% [markdown]
# #### Multiple Variable Assign

# %%
x, y, z = 0, 0, 0
x, y, z
# Out:
# (0, 0, 0)

# %% [markdown]
# ### Data Types

# %% [markdown]
# ![img](http://s3.amazonaws.com/lyah/cow.png)
# (<a href="#citeproc_bib_item_2">Lipovaca 2011</a>)
#
# Python has [built-in](https://docs.python.org/3/library/datatypes.html) datatypes. The most common ones include:

# %% [markdown]
# #### Int

# %% [markdown]
# `int`: whole number

# %%
age = 25
age
# Out:
# 25

# %% [markdown]
# Underscores can be used to write big numbers

# %%
speed_of_light = 299_792_458
speed_of_light
# Out:
# 299792458

# %% [markdown]
# #### Float

# %% [markdown]
# `float`: decimal number

# %%
salary = 40000.50
salary
# Out:
# 40000.5

# %% [markdown]
# #### String

# %% [markdown]
# `str`: represents text

# %%
name = 'Jack'
name
# Out:
# 'Jack'

# %% [markdown]
# `str` has useful [methods](https://docs.python.org/3/library/stdtypes.html#string-methods)
#
# [lower](https://docs.python.org/3/library/stdtypes.html#str.lower) returns a lowercase copy

# %%
name.lower()
# Out:
# 'jack'

# %% [markdown]
# [upper](https://docs.python.org/3/library/stdtypes.html#str.upper) returns an uppercase copy

# %%
name.upper()
# Out:
# 'JACK'

# %% [markdown]
# [title](https://docs.python.org/3/library/stdtypes.html#str.upper) returns a version where each word starts with an uppercase character and the remaining are lowercase

# %%
name.title()
# Out:
# 'Jack'

# %%
"monty python".title()
# Out:
# 'Monty Python'

# %% [markdown]
# Some more interesting functions that can be applied to strings

# %%
s = "hello"
print(s.capitalize())  # Capitalize a string
print(s.rjust(7))      # Right-justify a string, padding with spaces
print(s.center(7))     # Center a string, padding with spaces
print(s.replace('l', '5'))  # Replace all instances of one substring with another
print('  world '.strip())  # Strip leading and trailing whitespace
# Out:
# Hello
#   hello
#  hello
# he55o
# world

# %% [markdown]
# #### Bool

# %% [markdown]
# `bool`: True or False value

# %%
learning_python = True

# %% [markdown]
# #### Variables in Strings

# %% [markdown]
# `f-strings` put variables in strings

# %%
f"My name is {name} and I am {age} years old"
# Out:
# 'My name is Jack and I am 25 years old'

# %% [markdown]
# #### Determining Types

# %% [markdown]
# `type()`: returns the type of an object

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
type(salary)
# Out:
# float

# %% [markdown]
# #### Simple Conversions

# %% [markdown]
# Convert different types of data by using casting functions, such as `int`, `float`, and `str`.

# %%
int('10')
# Out:
# 10

# %%
float('10.0')
# Out:
# 10.0

# %%
str(10)
# Out:
# '10'

# %%
str(10.0)
# Out:
# '10.0'

# %% [markdown]
# ### Assignment Operation Semantics

# %% [markdown]
# What do you expect the value of `y` would be at the end of the following code block?

# %%
x = 1
y = x

x = 2

print(y)
# Out:
# 1

# %% [markdown]
# **Note that for some types of variables, the assignment of one to another may link them such that changing one of them, ends up changing the other one. (For example, in the above code, this would have meant that executing the code above would have printed 2 and not 1). We will see this kind of behavior when we go over pandas Data Frames.**

# %% [markdown]
# ### Python Type Hints

# %%
foo = 2
foo
# Out:
# 2

# %% [markdown]
# Python does not require that you specify what kind of variable you are creating, e.g., whether it will contain an integer, a float or a text string.  In some other languages, the above would have to be written as `int foo = 22`.
#
# [Python Type hints](https://docs.python.org/3/library/typing.html): The Python runtime does not enforce function and variable type annotations. They can be used by third party tools such as type checkers, IDEs, linters, etc.

# %%
foo: int = 2
foo
# Out:
# 2

# %% [markdown]
# ## Arithmetic

# %% [markdown]
# ### Arithmetic Operators

# %% [markdown]
# Arithmetic operators are used with numeric values to perform common mathematical operations:
#
#
# | Operator|Name of Operation|Example|
# |---|---|---|
# | +|Addition|x + y|
# | -|Subtraction|x - y|
# | \*|Multiplication|x * y|
# | \/|Division|x / y|
# | %|Modulus|x % y|
# | **|Exponentiation|x ** y|
# | //|Floor division|x // y|

# %% [markdown]
# #### Addition

# %%
3 + 4.5
# Out:
# 7.5

# %% [markdown]
# ##### Text

# %%
h = 'hello'
hw = h + ' ' + 'world' + '5'  # String concatenation
print(hw, len(hw))
# Out:
# hello world5 12

# %% [markdown]
# #### Multiplication

# %%
3 * 4.5
# Out:
# 13.5

# %% [markdown]
# #### Exercise

# %%
x = 4
y = 8


addition = x + y # add code here
subtraction = x - y # add code here
multiplication = x * y # add code here

# Example of f-string
print(f"x + y = {addition}\nx - y = {subtraction}\nx * y = {multiplication}")
# Out:
# x + y = 12
# x - y = -4
# x * y = 32

# %% [markdown]
# #### Exercise: Write a program that converts Celsius to Farenheit

# %% [markdown]
# $$\text{Fahrenheit} = \text{Celsius} \times 1.8 + 32.00$$

# %%
celsius = 10.0

farenheit = celsius * 1.8 + 32.00
farenheit
# Out:
# 50.0

# %% [markdown]
# #### Division

# %% [markdown]
# The `/` operator

# %%
4 / 3
# Out:
# 1.3333333333333333

# %% [markdown]
# #### Modulus

# %% [markdown]
# finds the remainder of an operation
#
# $$\frac{26}{16} = 1 \text{ remainder } 10$$

# %%
26 % 16
# Out:
# 10

# %% [markdown]
# #### Exponentiation

# %% [markdown]
# $$2^{4}$$

# %%
2 ** 4
# Out:
# 16

# %% [markdown]
# #### Floor Division

# %% [markdown]
# Rounds result to the nearest whole number
#
# $$\frac{26}{16} = 1$$

# %%
26 // 16
# Out:
# 1

# %% [markdown]
# ### The `+=` operator
#
# Although it is not in the table, a very important operator is the `+=` operator. You will see it all the time in other people's code and that is why it deserves its own section.

# %%
i = 0
i
# Out:
# 0

# %%
i += 1
i
# Out:
# 1

# %% [markdown]
# This is equivalent to

# %%
i = i + 1
i
# Out:
# 2

# %% [markdown]
# both of these increment the `i` by 1.

# %%
i = 1
i *= 2
i
# Out:
# 2

# %%
i = 1
i = i * 2
i
# Out:
# 2

# %% [markdown]
# ### Binary Crash Course
#
# To hone our math and python arithmetic operators skills we need a target to practice on.
#
# Binary is real easy to implement into digital circuitry.
#
# In a nutshell, binary is a way to write a number **only using 0s and 1s.**
#
# #### Python Bin Function
#
# The python [bin](https://docs.python.org/3/library/functions.html#bin) function allows us to see how decimal numbers look like in binary
#
# For example:

# %%
bin(0) # 0 is 0
# Out:
# '0b0'

# %%
bin(1) # 1 is 1
# Out:
# '0b1'

# %% [markdown]
# Pay attention to the next part. We ran out of things to represet **2** in binary.
#
# When we reach **9** in decimal and run out of stuff to represent it, then we add another digit and make **10!**.
#
# so now let's `bin(2)`

# %%
bin(2)
# Out:
# '0b10'

# %% [markdown]
# We got **10** in decimal. Now let's continue doing binary numbers

# %%
bin(3), bin(4), bin(5)
# Out:
# ('0b11', '0b100', '0b101')

# %% [markdown]
# #### Unbinning your binary number
#
# If you ever get yourself a binary number and need to transform it back then adding int takes a base argument to do so

# %%
int("10", 2)
# Out:
# 2

# %% [markdown]
# Now let's take that mess we made where we `bin`'d 3, 4, and 5 and make them decimal again

# %%
int("11", 2), int("100", 2), int("101", 2)
# Out:
# (3, 4, 5)

# %% [markdown]
# ##### ¿ Exercise can you turn `111` into decimal?

# %%
int("111", 2)
# Out:
# 7

# %% [markdown]
# #### Making Decimal Numbers Using Math
#
# Let's make 2 into binary using math. Let's divide 2 by 2 until the result is 0.
#
# $$ 2 \div 2 = 1 \text{ remainder } 0$$
#
# We still haven't reached 0 yet. Divide by 2 one more time.
#
# $$ 1 \div 2 = 0 \text{ remainder } 1$$
#
# Then we can see that the first remainder **1** and second remainder **0** make up $10_2$ or 2.
#
# That's all fine and dandy but how can we get this in code?

# %%
n = 2 # number we are trying to convert
base = 1 # where we are in the number we are creating
result = 0 # where we copy the number into


result = result + base * (n % 2)
base = base * 10
n = n // 2
print(f"Number so far: {result}")
result = result + base * (n % 2)
base = base * 10
n = n // 2
print(f"Number so far: {result}")
# Out:
# Number so far: 0
# Number so far: 10

# %% [markdown]
# Things to pay attention to are the modulus operator (`%`) in the `result`. It allows us to extract the **remainder** of the calculation. It extracts the current digit to add to the `result`.
#
# Another thing to pay attention is the use of `//`. In python, the `/` in this problem would've given us trouble becuase it brings along the remainder. The `//` allows us to only get the integer part of the **quotient**

# %% [markdown]
# #### Making Decimal Numbers Using Math
#
# Lets get some practice using our python math operators to make binary numbers. In class, you may see a binary number written like this
#
# $$10_{2}$$
#
# To transform $(10)_2$ into decimal then

# %%
int("10", 2)
# Out:
# 2

# %% [markdown]
# but doing it with math is a bit more difficult
#
#
# $$ 1 \times 2^{1} + 0 \times 2^{0} $$

# %%
1 * 2 ** 1 + 0 * 2 ** 0
# Out:
# 2

# %% [markdown]
# now doing $11_2$
#
# $$1 \times 2^{1} + 1 \times 2^{0}$$

# %%
1 * 2 ** 1 + 1 * 2 ** 0
# Out:
# 3

# %% [markdown]
# $100_2$
#
# $$1 \times 2^{2} + 0 \times 2^{1} + 0 \times 2^{0}$$

# %%
1 * 2 ** 2 + 0 * 2 ** 0 + 0 * 2 ** 0
# Out:
# 4

# %% [markdown]
# Can you convert $101_2$ to decimal?

# %%
1 * 2 ** 2 + 0 * 2 ** 1 + 1 * 2 ** 0
# Out:
# 5

# %% [markdown]
# ### Files Crash Course

# %% [markdown]
# A common complaint people have about tech literacy is that ipads and phones work too well. As a result, users forgot what files are.  (<a href="#citeproc_bib_item_1">Chin 2021</a>)

# %% [markdown]
# #### Downloading files to local system

# %% [markdown]
# **Google Colab** provides functions to interact with the [outside world.](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=hEzpzWYWsYKg)
#
# `files.download` will invoke a browser download of the file to your local computer.

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')

# %% [markdown]
# #### Talking to Google Drive

# %% [markdown]
# The following is mouthful so don&rsquo;t fret if you don&rsquo;t understand any of this on the first read.
#
# The example below shows how to **mount** your **Google Drive** on your **runtime** using an authorization code, and how to write and read files there. Once executed, you will be able to see the new file `foo.txt`
#
# This only supports reading, writing, and moving files.
#
# **Note:** When using the **&rsquo;Mount Drive&rsquo;** button in the file browser, no authentication codes are necessary for notebooks that have only been edited by the current user.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Some people prefer using their computer through the command line. You can think of the [cat](https://en.wikipedia.org/wiki/Cat_(Unix)) command as your eyes in the command line, one of its uses is to see inside a file.

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/foo.txt
# Out:
# Hello Google Drive!

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
# Out:
# All changes made in this colab session should now be visible in Drive.

# %% [markdown]
# This is good enough for now and probably even for the rest of the course. However, to programmatically modify sharing settings or other metadata, use other options: [Loading data: Drive, Sheets, and Google Cloud Storage](https://colab.research.google.com/notebooks/io.ipynb)

# %% [markdown]
# ### Making Plots

# %% [markdown]
# A question you'll ask yourself is `can I do more than just output text?`
#
# With Python and Google Colab you can. Making plots is simple. All you need is a Comma-separated values (**csv**) file.
#
# for this exercise, we'll be uploading a `micky_mouse_dataset.csv` onto our google drives in the home folder where it's easy to find.

# %% [markdown]
# #### Reading in a CSV into a Pandas Dataframe
#
# Once we've uploaded our `mickey_mouse_dataset.csv`, we can read it into a Pandas DataFrame. We can use Pandas [read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) to fill in our data.
#
# A lot of people complain about Pandas documentation, but fret not, if you scroll to the bottom this method has an **example!**
#
# ```python
# pd.read_csv('data.csv')
# ```
#
# ##### File Paths
#
# In this example, I defined a variable named `file_path`. This is just a fancy word for where the file is located.

# %%
import pandas as pd

file_path = "/content/drive/My Drive/mickey_mouse_dataset.csv"
mickey_mouse_dataframe = pd.read_csv(file_path)
mickey_mouse_dataframe
# Out:
#   Character  Height_cm  Weight_kg  Age Favorite_Color
# 0    Mickey        100         20   91            Red
# 1    Minnie         95         18   90           Pink
# 2    Donald        105         22   85           Blue
# 3     Daisy        100         19   87         Purple
# 4     Goofy        110         25   95          Green
# 5     Pluto         80         15   80         Yellow

# %% [markdown]
# There exists many ways to visualize this mickey mouse dataset. This is how to do it in a [matplot lib bar chart](https://matplotlib.org/stable/plot_types/basic/bar.html#sphx-glr-plot-types-basic-bar-py).

# %%
import matplotlib.pyplot as plt

# plot
fig, ax = plt.subplots()

characters = mickey_mouse_dataframe['Character']
age = mickey_mouse_dataframe['Age']

ax.bar(characters, age, width=1, edgecolor="white", linewidth=0.7)

plt.show()

# %% [markdown]
# ## Relational Operators

# %% [markdown]
# | Operator|Name|
# |---|---|
# | \==|Equal To|
# | !=|Not Equal To|
# | &gt;|Greater Than|
# | &lt;|Less Than|
# | &gt;=|Greater Than or Equal To|
# | &lt;=|Lesser Than or Equal To|

# %% [markdown]
# ### Equal To

# %% [markdown]
# `==`

# %%
age == 25
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Age, dtype: bool

# %%
# sets value
car = 'Audi'

# checks for equality
car == 'audi'
# Out:
# False

# %%
car.lower() == 'audi'
# Out:
# True

# %% [markdown]
# ### Not Equal To

# %% [markdown]
# `!=`

# %%
age != 25
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# Name: Age, dtype: bool

# %% [markdown]
# ### Greater Than

# %% [markdown]
# `>`

# %%
age > 25
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# Name: Age, dtype: bool

# %% [markdown]
# ### Greater Than or Equal To

# %% [markdown]
# `>=`

# %%
age >= 25
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# Name: Age, dtype: bool

# %% [markdown]
# ### Less Than

# %% [markdown]
# `<`

# %%
age < 25
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Age, dtype: bool

# %% [markdown]
# ### Lesser Than or Equal To

# %% [markdown]
# `<=`

# %%
age <= 25
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Age, dtype: bool

# %% [markdown]
# ### TRIVIA!: Branchless programming

# %% [markdown]
# **Do not try this at home, but do at a friends house**
#
# In programming there are things called `conditional statements` and we&rsquo;ll get to those later.
#
# However, just for fun, you can mimic conditional statements with just math.
#
# In this example, we have a number $321$ and a variable named $x$
#
# if $x$ is **negative** then it evaluates to -321
#
# if $x$ is **positive** then it evaluates to 321
#
# $$ \begin{cases}
#       -321 & x < 0 \\
#       321 & x\geq 0
#    \end{cases}
# $$
#
# where $x < 0 = 0$ and $x >= 0 = 1$

# %%
x = 123
# 0 * -321 + 1 * 321
(x < 0) * -321 + (x >= 0) * 321
# Out:
# 321

# %% [markdown]
# This works because in Python, the expression `(x < 0)` returns a $1$ or $0$
#
# Now, lets change it such that $x < 0 = 1$ and $x >= 0 = 0$

# %%
x = -123
# 1 * -321 + 0 * 321
(x < 0) * -321 + (x >= 0) * 321
# Out:
# -321

# %% [markdown]
# ## Works Cited

# %% [markdown]
# <style>.csl-entry{text-indent: -1.5em; margin-left: 1.5em;}</style><div class="csl-bib-body">
#   <div class="csl-entry"><a id="citeproc_bib_item_1"></a>Chin, Monica. 2021. “File Not Found.” <i>The Verge</i>. <a href="https://www.theverge.com/22684730/students-file-folder-directory-structure-education-gen-z">https://www.theverge.com/22684730/students-file-folder-directory-structure-education-gen-z</a>.</div>
#   <div class="csl-entry"><a id="citeproc_bib_item_2"></a>Lipovaca, Miran. 2011. <i>Learn You a Haskell for Great Good! a Beginner’s Guide</i>. 1st ed. No Starch Press.</div>
# </div>
